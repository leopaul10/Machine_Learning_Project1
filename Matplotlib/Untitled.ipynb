# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
Day=[1,2,3,4,5,6,7]

# %%
Temp=[50,51,52,48,47,46,45]

# %%
plt.plot(Day,Temp)
plt.show()

# %%
plt.plot(Day,Temp,color='green',linestyle='dashed',marker='o',linewidth=2)
plt.show()

# %%
plt.plot(Day,Temp,color='green',linestyle='dashdot',marker='o',linewidth=2)
plt.show()

# %%
# plt.xlabel('Day')
plt.ylabel('Temperature')
plt.title('Weather info')
plt.plot(Day,Temp,color='green',linestyle='dashdot',marker='o',linewidth=2)
plt.show()

# %%
plt.plot(Day,Temp,color='green',linestyle='dashdot',marker='o',linewidth=2,alpha=0.5)
plt.show()

# %%
#Legend Grid

days=[1,2,3,4,5,6,7]
max_t=[50,51,52,48,47,49,46]
min_t=[43,42,40,44,33,35,37]
avg_t=[45,48,48,46,40,42,41]

plt.xlabel('Day')
plt.ylabel('Temperature')
plt.title('Weather info')

plt.plot(days,max_t,label='Max')
plt.plot(days,min_t,label='Min')
plt.plot(days,avg_t,label='Average')
plt.legend(shadow=True)
plt.grid()
plt.show()

# %%
company=['GOOGL','AMZN','MSFT','FB']
revenue=[90,136,89,27]
profit=[40,2,34,12]

plt.xlabel('Major Comapanies')
plt.ylabel('Revenue')
plt.title('Revenue model')

plt.bar(company,revenue,label='Revenue')
plt.legend()
plt.show()

# %%
plt.barh(company,revenue)
# Out:
# <BarContainer object of 4 artists>

# %%
xpos=np.arange(len(company))
xpos
# Out:
# array([0, 1, 2, 3])

# %%
company=['GOOGL','AMZN','MSFT','FB']
revenue=[90,136,89,27]
profit=[40,2,34,12]

plt.xticks(xpos,company)
plt.xlabel('Major Comapanies')
plt.ylabel('Revenue')
plt.title('Revenue model')

plt.bar(company,revenue,label='Revenue')
plt.bar(company,profit,label='Profit')
plt.legend()
plt.show()

# %%
company=['GOOGL','AMZN','MSFT','FB']
revenue=[90,136,89,27]
profit=[40,2,34,12]

plt.xticks(xpos,company)
plt.xlabel('Major Comapanies')
plt.ylabel('Revenue')
plt.title('Revenue model')

plt.bar(xpos-0.2,revenue,width=0.4,label='Revenue')
plt.bar(xpos+0.2,profit,width=0.4,label='Profit')
plt.legend()
plt.show()

# %%
# histogaram

blood_sugar=[113, 85, 90, 150, 149 ,88, 93, 115, 135, 80, 77, 82, 129]

# %%
plt.hist(blood_sugar)
# Out:
# (array([3., 3., 1., 0., 1., 1., 0., 2., 0., 2.]),
#  array([ 77. ,  84.3,  91.6,  98.9, 106.2, 113.5, 120.8, 128.1, 135.4,
#         142.7, 150. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(blood_sugar,rwidth=0.8)
# Out:
# (array([3., 3., 1., 0., 1., 1., 0., 2., 0., 2.]),
#  array([ 77. ,  84.3,  91.6,  98.9, 106.2, 113.5, 120.8, 128.1, 135.4,
#         142.7, 150. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(blood_sugar,bins=3,rwidth=0.8,color='pink')
# Out:
# (array([7., 2., 4.]),
#  array([ 77.        , 101.33333333, 125.66666667, 150.        ]),
#  <BarContainer object of 3 artists>)

# %%
plt.hist(blood_sugar,bins=[80,100,125,150],rwidth=0.8,color='yellow')
# Out:
# (array([6., 2., 4.]),
#  array([ 80, 100, 125, 150]),
#  <BarContainer object of 3 artists>)

# %%
blood_sugar_men=[113, 85, 90, 150, 149, 88, 93, 115, 135, 80, 77, 82, 129]
blood_sugar_women=[67, 98, 89, 120, 133, 150, 84, 69, 89, 79, 120, 112, 100]


plt.hist([blood_sugar_men,blood_sugar_women])
# Out:
# (array([[0., 3., 3., 1., 0., 2., 0., 1., 1., 2.],
#         [2., 1., 3., 2., 0., 1., 2., 1., 0., 1.]]),
#  array([ 67. ,  75.3,  83.6,  91.9, 100.2, 108.5, 116.8, 125.1, 133.4,
#         141.7, 150. ]),
#  <a list of 2 BarContainer objects>)

# %%
blood_sugar_men=[113, 85, 90, 150, 149, 88, 93, 115, 135, 80, 77, 82, 129]
blood_sugar_women=[67, 98, 89, 120, 133, 150, 84, 69, 89, 79, 120, 112, 100]

plt.xlabel('Sugar level')
plt.ylabel('Number of pateints')
plt.title('Charts')

plt.hist([blood_sugar_men,blood_sugar_women],bins=[80,100,125,150])
# Out:
# (array([[6., 2., 4.],
#         [4., 4., 2.]]),
#  array([ 80, 100, 125, 150]),
#  <a list of 2 BarContainer objects>)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#Boxplot

np.random.seed(10)
data = np.random.normal(100,20,200)

# %%
data
# Out:
# array([126.63173008, 114.30557949,  69.09199416,  99.832323  ,
#        112.42671948,  85.59828879, 105.31023171, 102.17097051,
#        100.08582862,  96.50799579, 108.6605238 , 124.06074748,
#         80.69868659, 120.56548156, 104.5726026 , 108.90275226,
#         77.26795576, 102.70273757, 129.69074004,  78.40390228,
#         60.44543439,  65.13255408, 105.32140328, 147.69934661,
#        122.47382507, 133.45244427, 101.98298432, 127.95992754,
#         94.57504024, 112.2640837 ,  94.65365623,  89.01381972,
#        102.65416592,  90.4771597 , 126.16946162, 103.90026558,
#        108.00419977,  93.24735326, 125.12944528,  85.36060996,
#        113.20463102,  92.98256217,  81.2113328 ,  90.21325566,
#         83.90817715,  95.74604723,  93.21719508, 106.24339873,
#        111.30305339,  97.05159485,  99.48189326, 105.78188408,
#         89.20241857, 114.1632004 , 116.84449477, 104.07161595,
#        147.8940733 , 118.34917875,  97.75455058,  92.75639106,
# ...

# %%
len(data)
# Out:
# 200

# %%
plt.hist(data)
# Out:
# (array([ 1.,  6.,  9., 14., 43., 45., 40., 26.,  8.,  8.]),
#  array([ 40.40806458,  51.30256023,  62.19705589,  73.09155154,
#          83.9860472 ,  94.88054285, 105.77503851, 116.66953416,
#         127.56402982, 138.45852547, 149.35302113]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(data,rwidth=0.8)
# Out:
# (array([ 1.,  6.,  9., 14., 43., 45., 40., 26.,  8.,  8.]),
#  array([ 40.40806458,  51.30256023,  62.19705589,  73.09155154,
#          83.9860472 ,  94.88054285, 105.77503851, 116.66953416,
#         127.56402982, 138.45852547, 149.35302113]),
#  <BarContainer object of 10 artists>)

# %%
plt.figure(figsize=(10,5))
plt.boxplot(data)
plt.show()

# %%
np.mean(data)
# Out:
# 101.48613846633367

# %%
np.median(data)
# Out:
# 101.8873682842476

# %%
np.random.seed(10)
data_1=np.random.normal(100,10,200)
data_2=np.random.normal(90,20,200)
data_3=np.random.normal(80,30,200)
data_4=np.random.normal(70,40,200)
plt.figure(figsize=(10,5))

data=[data_1,data_2,data_3,data_4]

plt.boxplot(data,vert=False,patch_artist=True)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#Pie chart

exp_vals=[1400,600,300,410,250]
exp_labels=['Home Rent','Food','Phone/Internet Bill','Car','Other Utilities']

plt.figure(figsize=(10,7))
plt.axis('equal')

plt.pie(exp_vals,labels=exp_labels,radius=1.2,autopct='%0.2f%%',shadow=True,explode=[0.1,0,0.2,0,0],startangle=45)
plt.legend()
#plt.show
plt.savefig('piechart_1.pdf')
