# %%
pip install numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np

# %%
myList=[1,2,3,4]
stringList=['apple','orange']

# %%
print(myList)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_18252/952508865.py in <module>
# ----> 1 print(myList)
#
# NameError: name 'myList' is not defined

# %%
type(myList)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_18252/1400672676.py in <module>
# ----> 1 type(myList)
#
# NameError: name 'myList' is not defined

# %%
dir(np)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_18252/590600001.py in <module>
# ----> 1 dir(np)
#
# NameError: name 'np' is not defined

# %%
help(np)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_18252/3626044743.py in <module>
# ----> 1 help(np)
#
# NameError: name 'np' is not defined

# %%
np.array(myList)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_18252/217129395.py in <module>
# ----> 1 np.array(myList)
#
# NameError: name 'np' is not defined

# %%
arr=np.array(myList)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_18252/2807139608.py in <module>
# ----> 1 arr=np.array(myList)
#
# NameError: name 'np' is not defined

# %%
print(arr)
type(arr)
# Out:
# [1 2 3 4]
# numpy.ndarray

# %%
print(arr)
print(type(arr))
# Out:
# [1 2 3 4]
# <class 'numpy.ndarray'>
